# %% [markdown]
# ---
# # Caso Student Score Classification
#
# En esta actividad, tomaremos un set de datos de las horas de estudio de los alumnos versus el resultado que tiene en su evaluación para elaborar un modelo predictivo de clasificación. En este modelo, a partir de la cantidad de horas que un estudiante dedica, queremos predecir si el estudiante aprobará la materia o no. Tome como supuesto que la asignatura se aprueba **con nota igual o superior a 55 pts**.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_scores.csv')

# %% [markdown]
# ### Análisis básico del frame de datos
#
# Verifique:
# - despliegue 5 registros aleatorios
# - imprima las dimensiones del dataframe
# - despliegue la estructura del dataframe

# %%
# Out:
#    Hours  Scores
# 0    2.5      58
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      65

# %% [markdown]
# ### Wrangling
#
# Cree una nueva columna que se llame **Aprueba**, que contenga el valor 1 si aprueba y 0 si no aprueba. Recuerde que la nota de aprobación es igual o mayor que 55.

# %%
# Out:
#     Hours  Scores  Aprueba
# 0     2.5      58        0
# 1     5.1      47        0
# 2     3.2      27        0
# 3     8.5      75        1
# 4     3.5      65        1
# 5     1.5      20        0
# 6     9.2      88        1
# 7     5.5      60        1
# 8     8.3      81        1
# 9     2.7      25        0
# 10    7.7      85        1
# 11    5.9      62        1
# 12    4.5      41        0
# 13    3.3      42        0
# 14    1.1      17        0
# 15    8.9      95        1
# 16    2.5      30        0
# 17    1.9      33        0
# 18    6.1      67        1
# 19    7.4      69        1
# 20    2.7      30        0
# 21    4.8      54        0
# 22    3.8      35        0
# 23    6.9      76        1
# 24    7.8      86        1
# 25    4.2      55        0
# 26    6.1      50        0
# 27    3.7      58        0
# 28    5.4      62        1
# 29    5.5      55        0

# %% [markdown]
# ### Análisis Exploratorio
#
# Realice un análisis univariado y bivariado de los datos. Algunas sugerencias mínimas:
# - Distribución de **Hours**
# - Distribución de **Scores**
# - Dispersión Hours vs Score diferenciando los que aprobaron
# - Diagrama de regresión
# - Cuenta de aprueba vs no aprueba
# - Otros elementos no considerados acá

# %% [markdown]
# ### Formulación del Modelo
#
# Formule un modelo predictivo en donde se busca predecir si un estudiante aprobará el examen a partir de la cantidad de horas de estudio.

# %%
# defina las variables del modelo
X = ??
y = ??

# %% [markdown]
# ### Validación Cruzada
#
# Realice la separación entre datos de entrenamiento y de test, utilice un 75% para el set de entrenamiento

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = ??

# %% [markdown]
# ### Entrenamiento
#
# Entrene un clasificador logístico para que aprenda el modelo a partir de los datos de entrenamiento.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Acceder a los coeficientes del modelo
# ahora imprimiremos los coeficientes ajustados del modelo
coeficientes = ??
intercepto = ??

print("Coeficientes:", coeficientes)
print("Intercepto:", intercepto)

# %% [markdown]
# ### Predicciones
#
# Ahora relizaremos algunas predicciones con el modelo entrenado para ver si un estudiante, a partir de las horas de estudio dedicadas, aprobaría o no el examen.

# %%
# primero, realizaremos un cálculo manual a partir de la función sigmoidea y de los parámetros ajustados del modelo
# construya una función que permita calcular la probabilidad de aprobar a partir de la cantidad de horas estudiadas
# utilice la función sigmoidea y los parametros
def calcula_proba_aprobar(horas):
    # implemente
    pass

# %%
# Prediga si un alumno que estudia 4.5 hora aprobaría la evaluación del curso con la función creada
# ¿aprobaría o no aprobaría?

print('Pronóstico con 4.5 horas de estudio:', calcula_proba_aprobar(4.5))

# %% [markdown]
# Ahora vamos a utilizar el método predict()

# %%
# Prediga si un alumno que estudia 4.5 hora aprobaría la evaluación del curso.

# %%
# realice predicciones sobre el X_test

# %% [markdown]
# ### Prediccion de probabilidades
#
# Una característica importante de la regresión logística es su capacidad para predecir probabilidades de pertenencia a una clase específica en lugar de simplemente hacer predicciones de clase binaria directamente. Esto se logra utilizando la función logística (también conocida como función sigmoide), que transforma las salidas lineales del modelo en valores de probabilidad en el rango de 0 a 1.
#
# Para facilitar el cálculo de probabilidades, la librería scikitlear proporciona el método **predict_proba()**, que es similar al métodos **predict()** sólo que retorna la probabilidad de obtener 0 y la probabilidad de obtener 1.

# %%
# ¿Cuál es la probabilidad que tiene un alumno que estudia 5 horas?
# utilice predict_proba()

# %%
# ¿con cuántas horas de estudio un alumno tiene 50% de probabilidad de aprobar?

# %%
# despliegue las predicciones de probabilidad sobre el set de test

# %%
# haga un diagrama de linea y grafique la probabilidad, 
# en el eje X situe la cantidad de horas de estudio y en el eje Y la probabilidad de aprobar

# %%
# este es un ejemplo
# Out:
# c:\Users\jorge\miniconda3\envs\machinelearning\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Evaluación del Modelo
#
# La evaluación de un modelo logístico, al igual que la evaluación de cualquier modelo de clasificación en el aprendizaje automático, implica medir su rendimiento en la tarea de clasificación de datos. En este caso, utilizaremos las siguientes:
# - Matriz de Confusión
# - Accuracy

# %%
from sklearn.metrics import confusion_matrix

# %%
# despliegue la matriz de confusión

# %%
# cómo interpreta la matriz de confusion?

# %%
# calcule el acuracy del modelo (como dato, por defecto el método score calcula dicho valor)

# %% [markdown]
# ### Conclusiones

# %%
# Escriba aquí sus conclusiones

# %% [markdown]
# ---
