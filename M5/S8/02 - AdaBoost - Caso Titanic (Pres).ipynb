# %% [markdown]
# # AdaBoost - Caso Titanic
#
# En este notebook, utilizaremos AdaBoost para entrenar un algoritmo de clasificación que permita establecer un modelo que prediga los sobrevivientes del dataset Titanic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Carga de Datos y Análisis Exploratorio

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ### Valores perdidos

# %% [markdown]
# La cabina no aporta mucho en el análisis, pero la edad es una variable importante para predecir si una persona sobrevivió o no a la trajedia. A continuación, una forma de "visualizar" los valores perdidos.

# %% [markdown]
# Haremos una imputación de la edad del pasajero en función del promedio de edad de la clase en la que viajaba.

# %%
edades = df.groupby('Pclass')['Age'].mean().round()
edades
# Out:
# Pclass
# 1    38.0
# 2    30.0
# 3    25.0
# Name: Age, dtype: float64

# %%
# creamos una funcion que imputa la edad en caso de estar nula
def imputar_edad(cols):
    edad = edad = cols.iloc[0]
    pclass = pclass = cols.iloc[1]
    if(pd.isnull(edad)):
        if(pclass==1):
            return 38
        if(pclass==2):
            return 30
        if(pclass==3):
            return 25
    else:
        return edad

# %%
df['Age'] = df[['Age','Pclass']].apply(imputar_edad, axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Formulación del modelo
#
# En esta sección seleccionaremos las variables que incorporaremos en la matriz de predictores "X" y en el vector de resultados "y", ya que no todas las columnas son de utilidad.

# %%
X = df[['Age','Sex','Fare']]
y = df['Survived']

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head(2)
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500      True
# 1  38.0  71.2833     False

# %% [markdown]
# ### Validación Cruzada

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Nótese que si utilizamos random_state 0 y 41, obtenemos un performance distinto para cada caso

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)  # 41, 0

# %% [markdown]
# ### Modelamiento con AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf = AdaBoostClassifier(random_state=0, algorithm='SAMME')

# %%
clf.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', random_state=0)

# %%
clf.score(X_train,y_train)
# Out:
# 0.7921348314606742

# %%
# score en set de test
clf.score(X_test,y_test)
# Out:
# 0.7932960893854749

# %% [markdown]
# ## Hiperparámetros

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = AdaBoostClassifier(random_state = 0,
                         estimator = RandomForestClassifier(),
                         n_estimators = 100,
                         learning_rate = 0.01,
                         algorithm = 'SAMME')

# %%
clf.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', estimator=RandomForestClassifier(),
#                    learning_rate=0.01, n_estimators=100, random_state=0)

# %%
# score en set de entrenamiento
clf.score(X_train,y_train)
# Out:
# 0.9775280898876404

# %%
# score en set de test
clf.score(X_test,y_test)
# Out:
# 0.8100558659217877

# %%
importance_ada = clf.feature_importances_

# %%
def plot_feature_importance(importances, feature_names, model_name):
    indices = np.argsort(importances)[::-1]  # Sort feature importances in descending order
    plt.figure(figsize=(10, 6))
    plt.title(f"{model_name} Feature Importances")
    plt.bar(range(len(importances)), importances[indices], color="r", align="center")
    plt.xticks(range(len(importances)), [feature_names[i] for i in indices], rotation=45)
    plt.xlim([-1, len(importances)])
    plt.tight_layout()
    plt.show()

# %%
plot_feature_importance(importance_ada, X_train.columns, "AdaBoost")
