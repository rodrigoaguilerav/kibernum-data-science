# %% [markdown]
# ---
# # Caso API UN Comtrade - Limpieza de Datos
#
# UN COMTRADE es el seudónimo para la base de datos estadística de comercio de las Naciones Unidas, en las cuales más de 170 países o áreas del mundo, llamados reporters, proveen información a la división estadística de las Naciones Unidas con su información anual acerca de comercio e intercambio detallada en categorías de commodities o servicios con sus partners de comercio. Más información en la web oficial de UN Comtrade (https://comtrade.un.org/).
#
# Para el análisis de información, se extrajo previamente un archivo con datos de intercambio comercial de Chile entre los años 2016 y 2019. El análisis se centrará en las variables numéricas **NetWeight** y **TradeValue**, sin embargo, se sospecha de la consistencia de los datos.
#
#
# Se pide:
#
# - Hacer un análisis exploratorio de los datos, variables numéricas y categóricas
# - Hacer un análisis de valores nulos en el set de datos ¿Qué porcentaje de valores nulos posee las variables numéricas de estudio?
# - Hacer un análisis de outlaiers ¿Posee outiers las variables NetWeight y TradeValue?
# - Aplicar técnicas de limpieza
# - A partir de los datos limpios, obtener el valor total y peso de las exportaciones de commodities de Chile para el año 2019 y 2020.
# - Guardar datos limpios en un archivo Excel
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('Comtrade-CL.csv')

# %%
df.head(2).T
# Out:
#                                       0                1
# Classification                       H4               H4
# Year                               2016             2016
# Period                             2016             2016
# Period Desc.                       2016             2016
# Aggregate Level                       5                5
# Is Leaf Code                          0                0
# Trade Flow Code                       0                0
# Trade Flow                            X                X
# Reporter Code                       152              152
# Reporter                          Chile            Chile
# Reporter ISO                        CHL              CHL
# Partner Code                          8               24
# Partner                         Albania           Angola
# Partner ISO                         ALB              AGO
# 2nd Partner Code                      0                0
# ...
