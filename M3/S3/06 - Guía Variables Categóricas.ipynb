# %% [markdown]
# ---
# # Guía Autoestudio: Variables Categóricas
#
# En un modelo de regresión múltiple, las variables categóricas son aquellas que representan características que no son numéricas, sino que se clasifican en diferentes categorías o grupos. Estas variables pueden tomar valores de una lista finita y representan características cualitativas o de naturaleza no numérica.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# Para este propósito, vamos a cargar un set de datos de Altura y Peso con mediciones que distinguen el género.

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# #### 1. Realice un análisis exploratorio distinguiendo las características del grupo masculino y femenino

# %% [markdown]
# ### Modelo Simple

# %% [markdown]
# #### 2. Formulación del Modelo Simple
#
# Formule el modelo en donde considere solamente la variable Height.

# %%
# ajuste el modelo

# %%
# Despliegue el reporte

# %%
# Calcule el coeficiente de determinación R-cuadrado

# %%
# Calcule las métricas de error

# %% [markdown]
# ### Modelo Multivariado
#
# Este modelo lo formularemos incorporando adicionalmente la variable Gender.

# %%
# Formule el modelo
# Escríbalo acá
#
#

# %% [markdown]
# #### 3. Preprocesamiento columnas categóricas
#
# Cuando se utilizan variables categóricas en un modelo de regresión múltiple, es necesario convertirlas en variables indicadoras (también conocidas como variables dummy) antes de incluirlas en el modelo. Esto se hace asignando a cada categoría de la variable categórica una nueva variable binaria (0 o 1) que indica si una observación pertenece o no a esa categoría.
#
# Para esto, utilice la función get_dummies() que se encuentra disponible en la librería Pandas. Se adjunta link a la documentación:
#
# https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html

# %%
# aplique la función get_dummies() al dataframe para transformar las columnas categóricas

# %%
# despliegue el resultado del dataframe

# %% [markdown]
# Como se puede apreciar, se crearon dos nuevas columnas con valores 0 y 1, en donde 1 indica que el valor es True. Por ejemplo, el primer registro cuyo valor original era Gender=Male, ahora dio origen a las columnas Gender_Male=1 y Gender_Female=0. En términos generales, se crearán tantas columnas binarias como valores únicos categóricos se encuentren.
#
# Sin embargo, hay que considerar que en este ejemplo, las columnas Gender_Male y Gender_Female están perfectamente correlacionadas, pues si Gender_Male es 1, entonces Gender_Female es 0. Por lo tanto, es necesario eliminar una de las variables para evitar la multicolinearidad de las variables. No importa cuántos valores categóricos tenga la variable original, siempre deberá eliminarse una de las columnas al momento de binarizar. Por ejemplo, si existe una columna con 10 valores categóricos, deberán quedar 9 columnas nuevas después de eliminar una de ellas. Es decir, n - 1 columnas (siendo n la cantidad de valores categóricos de la variable).

# %%
# repita el paso anterior, pero esta vez, empleando el parámetro drop_first=True en la función get_dummies()

# %%
# Despliegue el dataframe y verifique que efectivamente queda solamente una columna binarizada

# %% [markdown]
# #### 4. Ajuste del modelo regresivo
#
# Utilice la librería statsmodels para formular el modelo regresivo y ajustar los parámetros. Recuerde incorporar ambos predictores

# %%
# Ajuste el modelo

# %%
# Despliegue el sumario de parámetros

# %% [markdown]
# #### 5. Comparación de resultados entre ambos modelos
#
# Compare los coeficientes de determinación y error del modelo con una y con dos variables. ¿Se aprecian mejoras en el modelo con dos variables?

# %%
# Responda acá
#
#

# %% [markdown]
# #### 6. Visualización de los modelos regresivos
#
# Ahora compararemos el modelo obtenido con una variable y con dos variables

# %%
# grafique un diagrama de dispersión con el modelo univariado, agregue la recta regresiva

# %%
# grafique un diagrama de dispersión con el modelo multivariado, pero sólo considerando los datos con Gender=Male, agregue la recta regresiva

# %%
# grafique un diagrama de dispersión con el modelo multivariado, pero sólo considerando los datos con Gender=Female, agregue la recta regresiva

# %% [markdown]
# #### 7. Conclusiones
#
# ¿Qué se puede concluir del efecto de una variable categórica en el modelo? ¿Cómo es la pendiente en el modelo multivariado? ¿Varía la pendiente en el caso de mediciones Male o Female?

# %% [markdown]
# # escriba acá sus conclusiones

# %% [markdown]
# ---
