# %%
#-------------------------------------
#------------- Actividad 2 -----------
#-------------------------------------
# Enunciado:
# Una urna contiene 5 bolas rojas, 3 bolas azules y 2 bolas verdes.
total_bolas = 5 + 3 + 2
# Se extrae una bola al azar de la urna.
# Calcula las siguientes probabilidades:
# 1. ¿Cuál es la probabilidad de que la bola extraída sea roja?
prob_roja = casos_roja / total_bolas
print(f"Probabilidad de que la bola extraída sea roja: {prob_roja:.2f}")

# 2. ¿Cuál es la probabilidad de que la bola extraída sea azul?
prob_azul = casos_azul / total_bolas
print(f"Probabilidad de que la bola extraída sea azul: {prob_azul:.2f}")

# 3. ¿Cuál es la probabilidad de que la bola extraída sea verde?
prob_verde = casos_verde / total_bolas
print(f"Probabilidad de que la bola extraída sea verde: {prob_verde:.2f}")

# 4. ¿Cuál es la probabilidad de que la bola extraída NO sea roja?
prob_no_roja = casos_no_roja / total_bolas
print(f"Probabilidad de que la bola extraída NO sea roja: {prob_no_roja:.2f}")

# 5. ¿Cuál es la probabilidad de que la bola extraída sea roja o azul?
prob_roja_azul = casos_roja_azul / total_bolas
print(f"Probabilidad de que la bola extraída sea roja o azul: {prob_roja_azul:.2f}")

# Probabilidad en la extracción de una bola de una urna

# Espacio muestral: 5 rojas, 3 azules, 2 verdes
total_bolas = 5 + 3 + 2

# 1. Probabilidad de que sea roja
casos_roja = 5

# 2. Probabilidad de que sea azul
casos_azul = 3

# 3. Probabilidad de que sea verde
casos_verde = 2

# 4. Probabilidad de que NO sea roja
casos_no_roja = total_bolas - casos_roja


# 5. Probabilidad de que sea roja o azul
casos_roja_azul = casos_roja + casos_azul
# Out:
# Probabilidad de que la bola extraída sea roja: 0.50
# Probabilidad de que la bola extraída sea azul: 0.30
# Probabilidad de que la bola extraída sea verde: 0.20
# Probabilidad de que la bola extraída NO sea roja: 0.50
# Probabilidad de que la bola extraída sea roja o azul: 0.80
