# %%
#-------------------------------------
#------------- Actividad 1 -----------
#-------------------------------------
# Enunciado:
# Supón que lanzas una moneda al aire. La moneda puede caer mostrando "cara" o "sello".
# Calcula las siguientes probabilidades:
# 1. ¿Cuál es la probabilidad de que salga "cara"?
# 2. ¿Cuál es la probabilidad de que salga "sello"?
# 3. ¿Cuál es la probabilidad de que salga cualquier resultado posible (evento seguro)?
# 4. ¿Cuál es la probabilidad de que salga un resultado imposible (por ejemplo, que la moneda caiga de canto)?

# Probabilidad en el lanzamiento de una moneda

# Espacio muestral: {"cara", "sello"}
espacio_muestral_moneda = ["cara", "sello"]
total_casos_moneda = len(espacio_muestral_moneda)

# 1. Probabilidad de que salga "cara"
casos_cara = 1
probabilidad_cara = casos_cara / total_casos_moneda
print(f"1. La probabilidad de que salga 'cara' es: {probabilidad_cara}")

# 2. Probabilidad de que salga "sello"
caso_sello = 1
probabilidad_sello = caso_sello / total_casos_moneda
print(f"2. La probabilidad de que salga 'sello' es: {probabilidad_sello}")

# 3. Probabilidad de que salga cualquier resultado (evento seguro)
caso_evento_seguro = total_casos_moneda
print(f"3. La probabilidad de que salga cualquier resultado posible (evento seguro) es: {probabilidad_evento_seguro}")

# 4. Probabilidad de que salga un resultado imposible (por ejemplo, "canto")
caso_imposible = 0
probabilidad_imposible = caso_imposible / total_casos_moneda
print(f"4. La probabilidad de que salga un resultado imposible es: {probabilidad_imposible}")
# Out:
# 1. La probabilidad de que salga 'cara' es: 0.5
# 2. La probabilidad de que salga 'sello' es: 0.5
# 3. La probabilidad de que salga cualquier resultado posible (evento seguro) es: 1.0
# 4. La probabilidad de que salga un resultado imposible es: 0.0
